# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Configure Your Local Environment

# %%
#Global Variables
domain = "https://api-internal.gis.earthdatacloud.nasa.gov"
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Generate A User Token and Set Authorization Bearer Variable
# >**Note:** After generating a user token, if you log into EGIS ArcGIS Server/Portal via a web broswer "you may" need to request a new token to continue in Notebook. The Web browser submits for a new token as well sometimes invalidating this one.

# %%
#url = "{server}/api/users/tokens".format(server=domain)
url = "{server}/users/tokens".format(server=domain)

payload = {}
payload["f"] = "json"
payload["username"] = ""
payload["password"] = "" # PROMPT for password getpass?
        
response = requests.post(url, data=json.dumps(payload)).json()
print(json.dumps(response, indent=2))

token = response["token"]
headers = {"Authorization": "Bearer {token}".format(token = token)}
# Out:
# {
#   "token": "DobP6dfmXr2II7M-IznlW7PsYVShFDAgfC7V5F0-TTrAtoAADXtR_x4Ie8uV3-ToZrt3gDjlmVLMJ9gYoFJt6KBh83StBvxJFuqV4XhRKsDInT0Vsy9jIzAngfInDBIK5bubjXJP1-1BvwJgiITAGeBn-KghD7gPQd2SGevVZXLbCbCmu7sunIMxkRHF8Ld4X8WlwSC6cmvr5G-jJiqNpw..",
#   "expires": 1706890025564
# }

# %% [markdown]
# # Get Information About You  (Authenticated)
# >**Note:** In the future we will not return this much information back to Service Curators.

# %%
url = "{server}/users/me".format(server=domain)
response = requests.get(url, headers=headers).json()

print(json.dumps(response, indent=2))
# Out:
# {
#   "type": "user",
#   "username": "pmcnair",
#   "userId": "360f5663b8d6499fb52ed36ab0edddaf",
#   "fullName": "Prentice McNair",
#   "email": "prentice.d.mcnair@nasa.gov",
#   "groups": [],
#   "roles": [],
#   "appTitle": null
# }

# %% [markdown]
# # Providers Endpoint

# %% [markdown]
# A provider onboarded to the our EGIS metadata database is required before a user can begin creating a collection.

# %% [markdown]
# ## Get A List of All Available Providers

# %%
url = "{server}/providers/".format(server=domain)
response = requests.get(url).json()
print("List of Providers")
response
# Out:
# List of Providers
# [{'provider_id': 'SATCORPS',
#   'name': None,
#   'cmr': False,
#   'description': None,
#   'contacts': None,
#   'link': None,
#   'type': None},
#  {'provider_id': 'ESDIS',
#   'name': None,
#   'cmr': False,
#   'description': None,
#   'contacts': None,
#   'link': None,
#   'type': None},
#  {'provider_id': 'GES_DISC',
#   'name': None,
#   'cmr': False,
#   'description': None,
#   'contacts': None,
#   'link': None,
#   'type': None}]

# %% [markdown]
# You should see the Provider you manually added to your local database below.

# %%
providers_df = pd.DataFrame(response)
providers_df
# Out:
#   provider_id  name    cmr description contacts  link  type
# 0    SATCORPS  None  False        None     None  None  None
# 1       ESDIS  None  False        None     None  None  None
# 2    GES_DISC  None  False        None     None  None  None

# %%
provider_id = response[2]["provider_id"]
print("My Provider ID: {provider_id}".format(provider_id=provider_id))
# Out:
# My Provider ID: GES_DISC

# %% [markdown]
# # Collections Endpoint

# %% [markdown]
# ## Create a new Collection (You Own) (Authenticated)

# %% [markdown]
# >**Note:** All collections need to be UNIQUE for the purposes of this demonstration as it will create a folder on the EGIS server. I recommend you use all capital letters for now as well. Example: MY_JASON_COLLECTION

# %%
collection_id = "MY_TEST2_COLLECTION3" #CMR Collection ID

url = "{server}/providers/{providerId}/collections".format(server=domain, providerId=provider_id)

payload = {}
payload["collectionId"] = collection_id
        
response = requests.post(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "collection_id": "MY_TEST2_COLLECTION3",
#   "created": "2024-02-01T17:11:58.710363",
#   "provider": "GES_DISC"
# }

# %% [markdown]
# ### Congratulations! You now own a Collection on EGIS

# %% [markdown]
# ## Get ALL Collections You Own (Authenticated)

# %%
url = "{server}/collections".format(server=domain)

response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# [
#   {
#     "collection_id": "M2T1NXSLV_T2M_MCNAIR",
#     "name": null,
#     "cmr": false,
#     "created": "2024-01-25T13:05:10.503439",
#     "updated": "2024-01-25T13:05:10.503439",
#     "version": null,
#     "website": null,
#     "description": null
#   },
#   {
#     "collection_id": "MY_TEST2_COLLECTION1",
#     "name": null,
#     "cmr": false,
#     "created": "2024-01-31T20:59:03.622487",
#     "updated": "2024-01-31T20:59:03.622496",
#     "version": null,
#     "website": null,
#     "description": null
#   },
#   {
#     "collection_id": "MY_TEST2_COLLECTION2",
#     "name": null,
#     "cmr": false,
#     "created": "2024-02-01T16:08:09.743290",
#     "updated": "2024-02-01T16:08:09.743301",
#     "version": null,
#     "website": null,
#     "description": null
#   },
#   {
#     "collection_id": "MY_TEST2_COLLECTION3",
#     "name": null,
#     "cmr": false,
#     "created": "2024-02-01T17:11:58.710363",
#     "updated": "2024-02-01T17:11:58.710372",
#     "version": null,
#     "website": null,
#     "description": null
#   }
# ]

# %%
collections_df = pd.DataFrame(response)
collections_df
# Out:
#           collection_id  name    cmr                     created  \
# 0  M2T1NXSLV_T2M_MCNAIR  None  False  2024-01-25T13:05:10.503439
# 1  MY_TEST2_COLLECTION1  None  False  2024-01-31T20:59:03.622487
# 2  MY_TEST2_COLLECTION2  None  False  2024-02-01T16:08:09.743290
# 3  MY_TEST2_COLLECTION3  None  False  2024-02-01T17:11:58.710363
#
#                       updated version website description
# 0  2024-01-25T13:05:10.503439    None    None        None
# 1  2024-01-31T20:59:03.622496    None    None        None
# 2  2024-02-01T16:08:09.743301    None    None        None
# 3  2024-02-01T17:11:58.710372    None    None        None

# %% [markdown]
# ## Get Information on a specific Collection you own (Authenticated)

# %%
url = "{server}/collections/{collectionId}".format(server=domain, collectionId = collection_id)
response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "collection": "MY_TEST2_COLLECTION3",
#   "name": null,
#   "created": "2024-02-01T17:11:58.710363",
#   "updated": "2024-02-01T17:11:58.710372",
#   "cmr": false,
#   "provider": "GES_DISC"
# }

# %% [markdown]
# ### Now that you have a collection created you can begin to create Mosaics and Services associated with this Collection.

# %% [markdown]
# # MOSAIC ENDPOINTS

# %% [markdown]
# ## Create A New Empty Mosaic (Authenticated)

# %% [markdown]
# >**Note:** Be sure to make your mosaic meets the following criteria: all lowercase, use underscores, and make it unique. Example: my_barnett_mosaic

# %%
mosaic_id = "my_test2_mosaic3"

url = "{server}/collections/{collectionId}/mosaics".format(server=domain, collectionId=collection_id)

payload = {
  "mosaic": {
    "mosaicId": mosaic_id
  }
}

# %% [markdown]
# >**Note:** Be aware that there can be a small delay waiting for the mosaic response once you run the POST request below.

# %%
# Make POST Request to Create Mosaic

response = requests.post(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "mosaicId": "my_test2_mosaic3",
#   "created": "2024-02-01T17:12:35.634014",
#   "updated": "2024-02-01T17:12:35.634023",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC"
# }

# %% [markdown]
# ### Congratulations! You have created an empty mosaic associated with your Collection.

# %% [markdown]
# ## Get ALL Mosaics You Own (Authenticated)

# %%
url = "{server}/mosaics".format(server=domain)

response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# [
#   {
#     "mosaicId": "my_test2_mosaic1",
#     "created": "2024-01-31T21:01:53.671568",
#     "updated": "2024-01-31T21:47:25.681760",
#     "collectionId": "MY_TEST2_COLLECTION1",
#     "providerId": "SATCORPS"
#   },
#   {
#     "mosaicId": "my_test2_mosaic2",
#     "created": "2024-02-01T16:09:05.539783",
#     "updated": "2024-02-01T16:30:30.262361",
#     "collectionId": "MY_TEST2_COLLECTION2",
#     "providerId": "SATCORPS"
#   },
#   {
#     "mosaicId": "my_test2_mosaic3",
#     "created": "2024-02-01T17:12:35.634014",
#     "updated": "2024-02-01T17:12:35.634023",
#     "collectionId": "MY_TEST2_COLLECTION3",
#     "providerId": "GES_DISC"
#   },
#   {
#     "mosaicId": "testmosaic",
#     "created": "2024-01-25T13:13:05.975108",
#     "updated": "2024-01-29T13:22:30.855927",
#     "collectionId": "M2T1NXSLV_T2M_MCNAIR",
#     "providerId": "GES_DISC"
#   },
#   {
#     "mosaicId": "M2T1NXSLV_T2M_MCNAIR",
#     "created": "2024-01-25T13:06:58.698145",
#     "updated": "2024-01-29T14:51:24.646580",
#     "collectionId": "M2T1NXSLV_T2M_MCNAIR",
#     "providerId": "GES_DISC"
#   }
# ]

# %%
mosaics_df = pd.DataFrame(response)
mosaics_df
# Out:
#                mosaicId                     created  \
# 0      my_test2_mosaic1  2024-01-31T21:01:53.671568
# 1      my_test2_mosaic2  2024-02-01T16:09:05.539783
# 2      my_test2_mosaic3  2024-02-01T17:12:35.634014
# 3            testmosaic  2024-01-25T13:13:05.975108
# 4  M2T1NXSLV_T2M_MCNAIR  2024-01-25T13:06:58.698145
#
#                       updated          collectionId providerId
# 0  2024-01-31T21:47:25.681760  MY_TEST2_COLLECTION1   SATCORPS
# 1  2024-02-01T16:30:30.262361  MY_TEST2_COLLECTION2   SATCORPS
# 2  2024-02-01T17:12:35.634023  MY_TEST2_COLLECTION3   GES_DISC
# 3  2024-01-29T13:22:30.855927  M2T1NXSLV_T2M_MCNAIR   GES_DISC
# 4  2024-01-29T14:51:24.646580  M2T1NXSLV_T2M_MCNAIR   GES_DISC

# %% [markdown]
# ## Get Information on a specific Mosaic you Own (Authenticated)

# %% [markdown]
# This Endpoint will provide you with all the properties associated with the mosaic.

# %%
url = "{server}/mosaics/{mosaicId}".format(server=domain, mosaicId=mosaic_id)

response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "allowedCompressionMethods": "None;JPEG;LZ77;LERC",
#   "allowedFields": "name;minps;maxps;lowps;highps;tag;groupname;productname;centerx;centery;zorder;st_area(shape);st_perimeter(shape)",
#   "allowedMensurationCapabilities": "None",
#   "allowedMosaicMethods": "NorthWest;Center;LockRaster;ByAttribute;Nadir;Viewpoint;Seamline;None",
#   "applyColorCorrection": false,
#   "blendWidth": 10.0,
#   "blendWidthUnits": "Pixels",
#   "cellSizeToleranceFactor": 0.8,
#   "clipToBoundary": true,
#   "clipToFootprint": false,
#   "defaultCompressionMethod": "None",
#   "defaultMensurationCapability": "None",
#   "defaultMosaicMethod": "NorthWest",
#   "defaultProcessingTemplate": "None",
#   "defaultResamplingMethod": "Bilinear Interpolation",
#   "endTimeField": "",
#   "footprintMayContainNoData": true,
#   "GCSTransforms": [],
#   "isMultidimensional": false,
#   "JPEGQuality": 75,
#   "LERCTolerance": 0.01,
#   "maxDownloadImageCount": 20,
#   "maxDownloadSizeLimit": 2048,
#   "maxRastersPerMosaic": 20,
#   "maxRecordsReturned": 1000,
#   "maxRequestSizeX": 15000,
#   "maxRequestSizeY": 4100,
#   "minimumPixelContribution": 1,
#   "mosaicOperator": "First",
#   "orderBaseValue": 0.0,
#   "orderField": "MinPS",
#   "processingTemplates": "",
#   "rasterMetadataLevel": "Basic",
#   "referenced": false,
#   "sortAscending": true,
#   "startTimeField": "",
#   "timeValueFormat": "",
#   "useTime": false,
#   "viewpointSpacingX": 600.0,
#   "viewpointSpacingY": 300.0,
#   "mosaicId": "my_test2_mosaic3",
#   "created": "2024-02-01T17:12:35.634014",
#   "updated": "2024-02-01T17:12:35.634023",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC"
# }

# %% [markdown]
# Be sure to note that this empty Mosaic currently does not have any multidimensional information associated with it.

# %%
response["isMultidimensional"]
# Out:
# False

# %% [markdown]
# # Create Raster Proxies

# %%
url = "{server}/collections/{collectionId}/rasters/proxies".format(server=domain,collectionId=collection_id)

payload = {
  "variables": [
    "T2M"
  ],
  "rasterType": {
    "access": {
      "type": "vsis3",
      "bucket": "gesdisc-cumulus-prod-protected"
    },
    "type": "netcdf"
  },
  "rasters": [
    {
      "inputPath": "/MERRA2/M2T1NXSLV.5.12.4/1982/03/MERRA2_100.tavg1_2d_slv_Nx.19820302.nc4",
      "dimensions": [
        {
          "dimension": "time",
          "values": [
			"1982-03-02 00:30:00",
			"1982-03-02 01:30:00",
			"1982-03-02 02:30:00",
            "1982-03-02 03:30:00",
            "1982-03-02 04:30:00",
            "1982-03-02 05:30:00",
            "1982-03-02 06:30:00",
            "1982-03-02 07:30:00",
            "1982-03-02 08:30:00",
            "1982-03-02 09:30:00",
            "1982-03-02 10:30:00",
            "1982-03-02 11:30:00",
            "1982-03-02 12:30:00",
            "1982-03-02 13:30:00",
            "1982-03-02 14:30:00",
            "1982-03-02 15:30:00",
			"1982-03-02 16:30:00",
			"1982-03-02 17:30:00",
			"1982-03-02 18:30:00",
			"1982-03-02 19:30:00",
			"1982-03-02 20:30:00",
			"1982-03-02 21:30:00",
			"1982-03-02 22:30:00",
			"1982-03-02 23:30:00"
          ]
        }
      ]
    },
	{
      "inputPath": "/MERRA2/M2T1NXSLV.5.12.4/1982/03/MERRA2_100.tavg1_2d_slv_Nx.19820303.nc4",
      "dimensions": [
        {
          "dimension": "time",
          "values": [
			"1982-03-03 00:30:00",
			"1982-03-03 01:30:00",
			"1982-03-03 02:30:00",
            "1982-03-03 03:30:00",
            "1982-03-03 04:30:00",
            "1982-03-03 05:30:00",
            "1982-03-03 06:30:00",
            "1982-03-03 07:30:00",
            "1982-03-03 08:30:00",
            "1982-03-03 09:30:00",
            "1982-03-03 10:30:00",
            "1982-03-03 11:30:00",
            "1982-03-03 12:30:00",
            "1982-03-03 13:30:00",
            "1982-03-03 14:30:00",
            "1982-03-03 15:30:00",
			"1982-03-03 16:30:00",
			"1982-03-03 17:30:00",
			"1982-03-03 18:30:00",
			"1982-03-03 19:30:00",
			"1982-03-03 20:30:00",
			"1982-03-03 21:30:00",
			"1982-03-03 22:30:00",
			"1982-03-03 23:30:00"
          ]
        }
      ]
    }
  ]
}
        
response = requests.post(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "jobStatus": "running",
#   "jobId": "j08024ad6bd50479d9385f7aa9c925ab6",
#   "checkProgress": "/rasters/proxies/jobs/j08024ad6bd50479d9385f7aa9c925ab6"
# }

# %% [markdown]
# ## Check Job Status

# %%
job_id= response["jobId"]
url = "{server}/rasters/proxies/jobs/{jobId}".format(server=domain,collectionId=collection_id, jobId = job_id)


table_input = requests.get(url, headers=headers).json()

print(json.dumps(table_input, indent=2))
# Out:
# {
#   "jobStatus": "complete",
#   "variables": [
#     "T2M"
#   ],
#   "rasterType": {
#     "type": "proxy",
#     "access": {
#       "type": "direct"
#     }
#   },
#   "rasters": [
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302003000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 00:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302013000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 01:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302023000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 02:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302033000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 03:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302043000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 04:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302053000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 05:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302063000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 06:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302073000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 07:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302083000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 08:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302093000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 09:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302103000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 10:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302113000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 11:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302123000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 12:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302133000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 13:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302143000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 14:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302153000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 15:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302163000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 16:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302173000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 17:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302183000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 18:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302193000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 19:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302203000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 20:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302213000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 21:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302223000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 22:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302233000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-02 23:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303003000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 00:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303013000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 01:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303023000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 02:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303033000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 03:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303043000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 04:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303053000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 05:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303063000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 06:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303073000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 07:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303083000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 08:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303093000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 09:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303103000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 10:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303113000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 11:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303123000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 12:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303133000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 13:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303143000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 14:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303153000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 15:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303163000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 16:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303173000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 17:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303183000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 18:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303193000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 19:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303203000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 20:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303213000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 21:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303223000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 22:30:00"
#           ]
#         }
#       ]
#     },
#     {
#       "inputPath": "MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303233000.mrf",
#       "dimensions": [
#         {
#           "dimension": "time",
#           "values": [
#             "1982-03-03 23:30:00"
#           ]
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Take the newly created rasters proxies and input them into the create tables. Ensure You remove the job status line from the top.

# %%
url = "{server}/collections/{collectionId}/rasters/tables".format(server=domain,collectionId=collection_id)

if table_input["jobStatus"] == "complete":
    table_input.pop("jobStatus")

response = requests.post(url, data=json.dumps(table_input), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "status": "success",
#   "tableId": "341a7187b58f4f1da6a402e22da89a21",
#   "columns": [
#     "index",
#     "Variable",
#     "Raster",
#     "Collection",
#     "Dimensions",
#     "StdTime"
#   ],
#   "data": [
#     [
#       0,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302003000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 00:30:00"
#     ],
#     [
#       1,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302013000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 01:30:00"
#     ],
#     [
#       2,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302023000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 02:30:00"
#     ],
#     [
#       3,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302033000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 03:30:00"
#     ],
#     [
#       4,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302043000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 04:30:00"
#     ],
#     [
#       5,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302053000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 05:30:00"
#     ],
#     [
#       6,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302063000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 06:30:00"
#     ],
#     [
#       7,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302073000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 07:30:00"
#     ],
#     [
#       8,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302083000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 08:30:00"
#     ],
#     [
#       9,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302093000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 09:30:00"
#     ],
#     [
#       10,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302103000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 10:30:00"
#     ],
#     [
#       11,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302113000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 11:30:00"
#     ],
#     [
#       12,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302123000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 12:30:00"
#     ],
#     [
#       13,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302133000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 13:30:00"
#     ],
#     [
#       14,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302143000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 14:30:00"
#     ],
#     [
#       15,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302153000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 15:30:00"
#     ],
#     [
#       16,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302163000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 16:30:00"
#     ],
#     [
#       17,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302173000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 17:30:00"
#     ],
#     [
#       18,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302183000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 18:30:00"
#     ],
#     [
#       19,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302193000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 19:30:00"
#     ],
#     [
#       20,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302203000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 20:30:00"
#     ],
#     [
#       21,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302213000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 21:30:00"
#     ],
#     [
#       22,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302223000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 22:30:00"
#     ],
#     [
#       23,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203024_T2M_19820302233000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-02 23:30:00"
#     ],
#     [
#       24,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303003000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 00:30:00"
#     ],
#     [
#       25,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303013000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 01:30:00"
#     ],
#     [
#       26,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303023000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 02:30:00"
#     ],
#     [
#       27,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303033000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 03:30:00"
#     ],
#     [
#       28,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303043000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 04:30:00"
#     ],
#     [
#       29,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303053000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 05:30:00"
#     ],
#     [
#       30,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303063000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 06:30:00"
#     ],
#     [
#       31,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303073000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 07:30:00"
#     ],
#     [
#       32,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303083000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 08:30:00"
#     ],
#     [
#       33,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303093000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 09:30:00"
#     ],
#     [
#       34,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303103000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 10:30:00"
#     ],
#     [
#       35,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303113000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 11:30:00"
#     ],
#     [
#       36,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303123000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 12:30:00"
#     ],
#     [
#       37,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303133000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 13:30:00"
#     ],
#     [
#       38,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303143000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 14:30:00"
#     ],
#     [
#       39,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303153000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 15:30:00"
#     ],
#     [
#       40,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303163000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 16:30:00"
#     ],
#     [
#       41,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303173000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 17:30:00"
#     ],
#     [
#       42,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303183000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 18:30:00"
#     ],
#     [
#       43,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303193000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 19:30:00"
#     ],
#     [
#       44,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303203000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 20:30:00"
#     ],
#     [
#       45,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303213000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 21:30:00"
#     ],
#     [
#       46,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303223000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 22:30:00"
#     ],
#     [
#       47,
#       "T2M",
#       "/collections/id/MY_TEST2_COLLECTION3/proxies/MERRA2_100.tavg1_2d_slv_Nx.198203034_T2M_19820303233000.mrf",
#       "MY_TEST2_COLLECTION3",
#       "StdTime",
#       "1982-03-03 23:30:00"
#     ]
#   ]
# }

# %% [markdown]
# ## Add rasters using tableID

# %%
url = "{server}/mosaics/{mosaicId}/rasters/".format(server=domain,mosaicId=mosaic_id)
tableId = response["tableId"]
payload = {
  "rasterType": {
    "type": "table",
    "tableId": tableId
  }
}

response = requests.post(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "mosaicId": "my_test2_mosaic3",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC",
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "running",
#   "checkProgress": "/mosaics/jobs/j3d14b508fffd475093cffc7ca61db4ac"
# }

# %% [markdown]
# ## Check Job Status of add rasters

# %%
job_id = response["jobId"]
url = "{server}/mosaics/jobs/{jobId}".format(server=domain, jobId = job_id)

while response["jobStatus"] != "complete":
    response = requests.get(url, headers=headers).json()
    print(json.dumps(response, indent=2))
# Out:
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "running",
#   "message": "Built 40 data source items"
# }
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "running",
#   "message": "Built 40 data source items"
# }
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "complete",
#   "message": "Updated 'my_test2_mosaic3'"
# }
# {
#   "jobId": "j3d14b508fffd475093cffc7ca61db4ac",
#   "jobStatus": "complete",
#   "message": "Updated 'my_test2_mosaic3'"
# }

# %% [markdown]
# ## Get Rasters on a specific Mosaic you Own (Authenticated)

# %%
url = "{server}/mosaics/{mosaicId}/rasters/".format(server=domain, mosaicId=mosaic_id)


response = requests.get(url, headers=headers).json()
#print(json.dumps(response, indent=2))
#print out as pandas table pass it columns and headers

rasters = pd.DataFrame(columns=response["columns"],data = response["data"])
rasters
# Out:
#      objectid                                       name  minps  maxps  lowps  \
# 0          24  T5bcf58c843814040b754bb5479dc93d5; OID=24    0.0    5.0    0.5
# 1          34  T5bcf58c843814040b754bb5479dc93d5; OID=34    0.0    5.0    0.5
# 2          44  T5bcf58c843814040b754bb5479dc93d5; OID=44    0.0    5.0    0.5
# 3          53    a3fa5d16e5024e969094af39b129bf5f; OID=5    0.0    5.0    0.5
# 4          58   a3fa5d16e5024e969094af39b129bf5f; OID=10    0.0    5.0    0.5
# ..        ...                                        ...    ...    ...    ...
# 139       445  T341a7187b58f4f1da6a402e22da89a21; OID=45    0.0    5.0    0.5
# 140       446  T341a7187b58f4f1da6a402e22da89a21; OID=46    0.0    5.0    0.5
# 141       447  T341a7187b58f4f1da6a402e22da89a21; OID=47    0.0    5.0    0.5
# 142       448  T341a7187b58f4f1da6a402e22da89a21; OID=48    0.0    5.0    0.5
# 143       440  T341a7187b58f4f1da6a402e22da89a21; OID=40    0.0    5.0    0.5
#
#      highps  category      tag groupname productname  centerx  centery zorder  \
# 0       0.5         1  Dataset                        -0.3125      0.0   None
# 1       0.5         1  Dataset                        -0.3125      0.0   None
# 2       0.5         1  Dataset                        -0.3125      0.0   None
# 3       0.5         1  Dataset                        -0.3125      0.0   None
# 4       0.5         1  Dataset                        -0.3125      0.0   None
# ..      ...       ...      ...       ...         ...      ...      ...    ...
# 139     0.5         1  Dataset                        -0.3125      0.0   None
# 140     0.5         1  Dataset                        -0.3125      0.0   None
# 141     0.5         1  Dataset                        -0.3125      0.0   None
# 142     0.5         1  Dataset                        -0.3125      0.0   None
# 143     0.5         1  Dataset                        -0.3125      0.0   None
#
#      typeid        itemts                           urihash           shape  \
# 0         1  45323.724640  ED31535B7978BD5C02AA0C963C200C5B  [-0.3125, 0.0]
# 1         1  45323.724647  E17DC7A64B73212B9610F30A5BA73C9B  [-0.3125, 0.0]
# 2         1  45323.724654  C858D6A86989BC423F0BAB433D569F61  [-0.3125, 0.0]
# 3         2  45323.729378  FEE84155247EBCB11DEA23F67F8855A5  [-0.3125, 0.0]
# 4         2  45323.729381  CB73EF44723922AFF6CD40A0CDADFDC6  [-0.3125, 0.0]
# ..      ...           ...                               ...             ...
# 139     402  45323.731282  70AB43877009F9C92D0FDF53E36DEFF8  [-0.3125, 0.0]
# 140     402  45323.731282  671E20F834EF0001809471A2F354C45F  [-0.3125, 0.0]
# 141     402  45323.731283  C27C0B61966B3F6CE52AE974ABDE5C4C  [-0.3125, 0.0]
# 142     402  45323.731283  4A97359E3EFCA67C1EE17A26A94627E2  [-0.3125, 0.0]
# 143     402  45323.731279  62753DEFAA58199068A2C344D2CA3875  [-0.3125, 0.0]
#
#     variable            collection dimensions       stdtime  st_area(shape)  \
# 0        T2M  MY_TEST2_COLLECTION3    StdTime  383959800000         64980.0
# 1        T2M  MY_TEST2_COLLECTION3    StdTime  383995800000         64980.0
# 2        T2M  MY_TEST2_COLLECTION3    StdTime  384031800000         64980.0
# 3        T2M  MY_TEST2_COLLECTION3    StdTime  383891400000         64980.0
# 4        T2M  MY_TEST2_COLLECTION3    StdTime  383909400000         64980.0
# ..       ...                   ...        ...           ...             ...
# 139      T2M  MY_TEST2_COLLECTION3    StdTime  384035400000         64980.0
# 140      T2M  MY_TEST2_COLLECTION3    StdTime  384039000000         64980.0
# 141      T2M  MY_TEST2_COLLECTION3    StdTime  384042600000         64980.0
# 142      T2M  MY_TEST2_COLLECTION3    StdTime  384046200000         64980.0
# 143      T2M  MY_TEST2_COLLECTION3    StdTime  384017400000         64980.0
#
#      st_perimeter(shape)
# 0                 1081.0
# 1                 1081.0
# 2                 1081.0
# 3                 1081.0
# 4                 1081.0
# ..                   ...
# 139               1081.0
# 140               1081.0
# 141               1081.0
# 142               1081.0
# 143               1081.0
#
# [144 rows x 23 columns]

# %%
url = "{server}/mosaics/{mosaicId}".format(server=domain, mosaicId=mosaic_id)

response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "allowedCompressionMethods": "None;JPEG;LZ77;LERC",
#   "allowedFields": "name;minps;maxps;lowps;highps;tag;groupname;productname;centerx;centery;zorder;st_area(shape);st_perimeter(shape);Variable;Collection;Dimensions;StdTime",
#   "allowedMensurationCapabilities": "Basic",
#   "allowedMosaicMethods": "NorthWest;Center;LockRaster;ByAttribute;Nadir;Viewpoint;Seamline;None",
#   "applyColorCorrection": false,
#   "blendWidth": 10.0,
#   "blendWidthUnits": "Pixels",
#   "cellSizeToleranceFactor": 0.8,
#   "clipToBoundary": true,
#   "clipToFootprint": true,
#   "defaultCompressionMethod": "None",
#   "defaultMensurationCapability": "Basic",
#   "defaultMosaicMethod": "NorthWest",
#   "defaultProcessingTemplate": "None",
#   "defaultResamplingMethod": "Bilinear Interpolation",
#   "endTimeField": "",
#   "footprintMayContainNoData": true,
#   "GCSTransforms": [],
#   "isMultidimensional": false,
#   "JPEGQuality": 75,
#   "LERCTolerance": 0.01,
#   "maxDownloadImageCount": 20,
#   "maxDownloadSizeLimit": 2048,
#   "maxRastersPerMosaic": 20,
#   "maxRecordsReturned": 1000,
#   "maxRequestSizeX": 15000,
#   "maxRequestSizeY": 4100,
#   "minimumPixelContribution": 1,
#   "mosaicOperator": "First",
#   "orderBaseValue": 0.0,
#   "orderField": "MinPS",
#   "processingTemplates": "",
#   "rasterMetadataLevel": "Basic",
#   "referenced": false,
#   "sortAscending": true,
#   "startTimeField": "",
#   "timeValueFormat": "",
#   "useTime": false,
#   "viewpointSpacingX": 600.0,
#   "viewpointSpacingY": 300.0,
#   "mosaicId": "my_test2_mosaic3",
#   "created": "2024-02-01T17:12:35.634014",
#   "updated": "2024-02-01T17:32:56.252978",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC"
# }

# %% [markdown]
# ## Build your multidimensional information/set multidimensional properties/calculate statistics/

# %%
url = "{server}/mosaics/{mosaicId}".format(server=domain, mosaicId=mosaic_id)

payload = {
	"operations":[
		"BMI"
	],
	"operationsArgs": {
		"buildMultidimensionalInfo": {
			"deleteMultidimensionalInfo": "NO_DELETE_MULTIDIMENSIONAL_INFO"
		}
	}
}

response = requests.patch(url ,data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "mosaicId": "my_test2_mosaic3",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC",
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "running",
#   "checkProgress": "/mosaics/jobs/jd2f7d9a4d8ca47e89e5fe53b6b6cf411"
# }

# %%
job_id = response["jobId"]

url = "{server}/mosaics/jobs/{jobId}".format(server=domain, jobId = job_id)

while response["jobStatus"] != "complete":
    response = requests.get(url, headers=headers).json()
    print(json.dumps(response, indent=2))
# Out:
# {
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "jd2f7d9a4d8ca47e89e5fe53b6b6cf411",
#   "jobStatus": "complete",
#   "message": "Updated 'my_test2_mosaic3'"
# }

# %%
url = "{server}/mosaics/{mosaicId}".format(server=domain, mosaicId=mosaic_id)

payload = {
  "operations": [
    "SMDP"
  ],
  "operationsArgs": {
	"setMosaicDatasetProperties": {
      "dataSourceType": "SCIENTIFIC",
      "useTime": "true"
    }
  }
}
response = requests.patch(url,data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "mosaicId": "my_test2_mosaic3",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC",
#   "jobId": "j05d15fe343d542948fda92ec80bacc25",
#   "jobStatus": "running",
#   "checkProgress": "/mosaics/jobs/j05d15fe343d542948fda92ec80bacc25"
# }

# %%
job_id = response["jobId"]

url = "{server}/mosaics/jobs/{jobId}".format(server=domain, jobId = job_id)

while response["jobStatus"] != "complete":
    response = requests.get(url, headers=headers).json()
    print(json.dumps(response, indent=2))
# Out:
# {
#   "jobId": "j05d15fe343d542948fda92ec80bacc25",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "j05d15fe343d542948fda92ec80bacc25",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "j05d15fe343d542948fda92ec80bacc25",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "j05d15fe343d542948fda92ec80bacc25",
#   "jobStatus": "complete",
#   "message": "Updated 'my_test2_mosaic3'"
# }

# %%
url = "{server}/mosaics/{mosaicId}".format(server=domain, mosaicId=mosaic_id)

payload = {
  "operations": [
    "CS"
  ],
 "operationsArgs": {
	"calculateStatistics": {
        "xSkipFactor": 1,
      "ySkipFactor": 1,
      "skipExisting": "SKIP_EXISTING"
        }
	}
}

response = requests.patch(url ,data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "mosaicId": "my_test2_mosaic3",
#   "collectionId": "MY_TEST2_COLLECTION3",
#   "providerId": "GES_DISC",
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "checkProgress": "/mosaics/jobs/ja477874f4417482fbbd4028ea6e06c53"
# }

# %%
job_id = response["jobId"]

url = "{server}/mosaics/jobs/{jobId}".format(server=domain, jobId = job_id)

while response["jobStatus"] != "complete":
    response = requests.get(url, headers=headers).json()
    print(json.dumps(response, indent=2))
# Out:
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Executing..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "running",
#   "message": "Compute statistics and histogram ..."
# }
# {
#   "jobId": "ja477874f4417482fbbd4028ea6e06c53",
#   "jobStatus": "complete",
#   "message": "Updated 'my_test2_mosaic3'"
# }

# %% [markdown]
# ## Publish Service

# %%
# POST /api/mosaics/{mosaicId}/services

url = "{server}/mosaics/{mosaicId}/services".format(server=domain,mosaicId=mosaic_id)

payload = {
  "service": {
    "serviceName": "test3_service",
    "type": "ImageServer",
    "description": "test2 Description..."
  }
}
        
response = requests.post(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "serviceId": "test3_service",
#   "serviceState": "STARTED",
#   "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/MY_TEST2_COLLECTION2/test3_service/ImageServer",
#   "phase": "build-test",
#   "created": "2024-02-01T16:33:42.024053",
#   "updated": "2024-02-01T16:33:42.024062",
#   "source": "my_test2_mosaic2",
#   "collectionId": "MY_TEST2_COLLECTION2"
# }

# %% [markdown]
# ## Update Portal Item Metadata

# %% [markdown]
# ### Get Item ID

# %%
#/api/portals/items

url = "{server}/portals/items".format(server=domain)

response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# [
#   {
#     "itemId": "61ab99cf1d1b4d6f90104d18bdb6798c",
#     "userId": "pmcnair",
#     "created": 1692114344787,
#     "modified": 1692898739891,
#     "title": "Daymet_Annual_V4R1_CRF",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "Daymet_Annual_V4R1_CopyRaster_crf",
#       "ImageServer"
#     ],
#     "snippet": "This dataset provides annual climate summaries derived from Daymet Version 4 R1 daily data at a 1 km x 1 km spatial resolution for five Daymet variables: minimum and maximum temperature, precipitation, vapor pressure, and snow water equivalent. Annual averages are provided for minimum and maximum temperature, vapor pressure, and snow water equivalent, and annual totals are provided for the precipitation variable. Each data file is provided as a single year by variable and covers the same period of record as the Daymet V4 R1 daily data.",
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/Daymet_Annual_V4R1_CopyRaster_crf/ImageServer"
#   },
#   {
#     "itemId": "ae79fdb04822477592a7efe19df89e58",
#     "userId": "pmcnair",
#     "created": 1692727502065,
#     "modified": 1692898720059,
#     "title": "Daymet_Annual_V4R1_PRCP",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "Daymet_Annual_V4R1_PRCP",
#       "ImageServer"
#     ],
#     "snippet": "Daymet PRCP var mosaic dataset.",
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/Daymet_Annual_V4R1_PRCP/ImageServer"
#   },
#   {
#     "itemId": "5b5f141654854453b9b49d59ca93e5ad",
#     "userId": "pmcnair",
#     "created": 1692798019693,
#     "modified": 1692898749809,
#     "title": "Daymet_Annual_V4R1_PRCP_CRF",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "Daymet_Annual_V4R1_PRCP_CopyRaster_crf",
#       "ImageServer"
#     ],
#     "snippet": "Daymet Annual Precipitation CRF copy.",
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/Daymet_Annual_V4R1_PRCP_CopyRaster_crf/ImageServer"
#   },
#   {
#     "itemId": "4ea9d6781fd143b1884f1c01c0a91ba2",
#     "userId": "pmcnair",
#     "created": 1692898373997,
#     "modified": 1692898694125,
#     "title": "Daymet_Annual_V4R1_TMAX",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "Daymet_Annual_V4R1_TMAX",
#       "ImageServer"
#     ],
#     "snippet": "Daymet Annual TMAX Variable",
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/Daymet_Annual_V4R1_TMAX/ImageServer"
#   },
#   {
#     "itemId": "92fd1f1b5e5e481aa7b35d01788673e2",
#     "userId": "pmcnair",
#     "created": 1695388591083,
#     "modified": 1695388606327,
#     "title": "PR",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "PR",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/PR/ImageServer"
#   },
#   {
#     "itemId": "192776e206524a8e99a5e6942dc02667",
#     "userId": "pmcnair",
#     "created": 1697470895329,
#     "modified": 1697470895329,
#     "title": "POWER_901_ANNUAL_WIND_UTC",
#     "type": "Image Service",
#     "description": "POWER annual wind.",
#     "tags": [
#       "POWER_901_ANNUAL_WIND_UTC",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/POWER/POWER_901_ANNUAL_WIND_UTC/ImageServer"
#   },
#   {
#     "itemId": "94de4b5e3ae34d5dbc80f9dd4a201227",
#     "userId": "pmcnair",
#     "created": 1701890225396,
#     "modified": 1701890225396,
#     "title": "OPERA_RTC_VV_231120_1833",
#     "type": "Image Service",
#     "description": "Opera Test Service",
#     "tags": [
#       "OPERA_RTC_VV_231120_1833",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/image/rest/services/UAT/OPERA_RTC_VV_231120_1833/ImageServer"
#   },
#   {
#     "itemId": "1e64c0097e034b7681f080ad3e872e0b",
#     "userId": "pmcnair",
#     "created": 1702574706732,
#     "modified": 1706019738692,
#     "title": "Daymet_Annual_V4R1_TMAX",
#     "type": "Image Service",
#     "description": null,
#     "tags": [
#       "Daymet_Annual_V4R1_TMAX",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/test_pub/Daymet_Annual_V4R1_TMAX/ImageServer"
#   },
#   {
#     "itemId": "50f35495e06c4c3a89c7da994b0c089b",
#     "userId": "pmcnair",
#     "created": 1706554893415,
#     "modified": 1706554893415,
#     "title": "workpls",
#     "type": "Image Service",
#     "description": "doesnt matter",
#     "tags": [
#       "workpls",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/M2T1NXSLV_T2M_MCNAIR/workpls/ImageServer"
#   },
#   {
#     "itemId": "67868f174d5b458a97c50bbac752fd4a",
#     "userId": "pmcnair",
#     "created": 1706737942026,
#     "modified": 1706737942026,
#     "title": "test2_service",
#     "type": "Image Service",
#     "description": "test2 Description...",
#     "tags": [
#       "test2_service",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/MY_TEST2_COLLECTION1/test2_service/ImageServer"
#   },
#   {
#     "itemId": "dfef99a3e1dd47da8fa698b5a83eddea",
#     "userId": "pmcnair",
#     "created": 1706805213742,
#     "modified": 1706805213742,
#     "title": "test3_service",
#     "type": "Image Service",
#     "description": "test2 Description...",
#     "tags": [
#       "test3_service",
#       "ImageServer"
#     ],
#     "snippet": null,
#     "accessInformation": null,
#     "licenseInfo": null,
#     "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/MY_TEST2_COLLECTION2/test3_service/ImageServer"
#   }
# ]

# %%
# POST /api/portals/items/{itemId}

item_id="dfef99a3e1dd47da8fa698b5a83eddea"

url = "{server}/portals/items/{itemId}".format(server=domain,itemId=item_id)

payload = {
  "description": "Test 2 is a Test",
  "snippet": "TEST brief summary about the item",
  "tags": [
    "TEST"
  ],
  "accessInformation": "Organization Only Test",
  "licenseInfo": "test license"
}
        
response = requests.patch(url, data=json.dumps(payload), headers=headers).json()
print(json.dumps(response, indent=2))
# Out:
# {
#   "itemId": "dfef99a3e1dd47da8fa698b5a83eddea",
#   "userId": "pmcnair",
#   "created": 1706805213742,
#   "modified": 1706805856724,
#   "title": "test3_service",
#   "type": "Image Service",
#   "description": "Test 2 is a Test",
#   "tags": [
#     "TEST"
#   ],
#   "snippet": "TEST brief summary about the item",
#   "accessInformation": "Organization Only Test",
#   "licenseInfo": "test license",
#   "serviceUrl": "https://gis.earthdata.nasa.gov/UAT/rest/services/MY_TEST2_COLLECTION2/test3_service/ImageServer"
# }
